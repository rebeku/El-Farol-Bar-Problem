# %%
import numpy as np
from matplotlib import pyplot as plt

from OOEFBP import EFBPSim

# %%
rng = np.random.default_rng(17)

class StrategyMaker:
    def __init__(self, sigma):
        self.sigma = sigma

    def make(self, rng, strategies, memory):
        
        if self.sigma > 0:
            center = rng.normal(1 / memory, self.sigma)
            radius = 1 + rng.chisquare(self.sigma)
        else:
            center = 1 / memory
            radius = 1
            
        self.min = center - radius
        self.max = center + radius
        return rng.uniform(self.min, self.max, size=(strategies, memory))


sm = StrategyMaker(1)
sm.make(rng, 5, 2)
# Out:
# array([[1.32374891, 1.0016003 ],
#        [1.36107627, 1.45014575],
#        [1.83548931, 2.09853544],
#        [0.58160186, 1.08385078],
#        [1.82034881, 0.72559042]])

# %%
sigma = 1
agents = 10000
s = 2
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 5
agents = 10000
s = 2
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 10
agents = 10000
s = 2
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %% [markdown]
# Right, so when there is a stable fixed point, heterogeneity may increase the probability that the system converges to exactly the fixed point instead of fluctuating around it.  Or maybe not...
#
# What about an unstable fixed point?

# %%
sigma = 1
agents = 10000
s = 5
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 5
agents = 10000
s = 5
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 10
agents = 10000
s = 5
memory = 2
n_trials=5
n_iter = max(100, memory * 3)
threshold = 60 * agents / 100

h = rng.choice(agents + 1, 2 * memory)
sm = StrategyMaker(sigma)

for _ in range(n_trials):
    sim = EFBPSim(
        memory=memory, 
        strategies=s,
        start=h, 
        n_iter=n_iter,
        agents=agents,
        strategy_func=sm.make,
        threshold=threshold,
        seed=rng.choice(10000))

    plt.figure()
    plt.plot(sim.hist)
    _ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sm.make(rng, s, memory)
# Out:
# array([[17.42126608, 20.46963844],
#        [ 5.87156755, 17.99254742],
#        [13.90383266,  4.01120772],
#        [13.9158946 , 12.33152222],
#        [12.22054451,  8.26709179]])

# %%
s = 10
sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1
s = 5
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 2
s = 5
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1.5
s = 5
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1.7
s = 5
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1.6
s = 5
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1.6
s = 5
n_iter = 500
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1.6
s = 5
n_iter = 500
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 1
s = 5
n_iter = 500
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")

# %%
sigma = 0
s = 5
n_iter = 500
sm = StrategyMaker(sigma)

sim = EFBPSim(
    memory=memory, 
    strategies=s,
    start=h, 
    n_iter=n_iter,
    agents=agents,
    strategy_func=sm.make,
    threshold=threshold,
    seed=rng.choice(10000))

plt.figure()
plt.plot(sim.hist)
_ = plt.title(f"{sim.hist[-6:]}    s={s}    agents={agents}")
