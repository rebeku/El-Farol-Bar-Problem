# %%
from OOEFBP import EFBPSim
from util import detect_cycle
import numpy as np
from matplotlib import pyplot as plt

# %%
rng = np.random.default_rng()

# %%
def make_normal_strategies(rng, strategies, memory, loc=0, scale=1):
    return rng.normal(loc=loc, scale=scale, size=(strategies, memory))

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

# %%
plt.plot(sim.hist)

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    # strategy_func=make_normal_strategies
)

plt.plot(sim.hist)

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)

# %%
def make_normal_unbiased(rng, strategies, memory, loc=0, scale=1):
    a = rng.normal(loc=loc, scale=scale, size=(strategies))
    return np.vstack([a, 1-a]).T

# %%
sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_unbiased
)

plt.plot(sim.hist)

# %%
sim = EFBPSim(
    memory=2, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[56 59 67 52 68]')

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[61 55 68 57 57]')

# %%
hist = rng.choice(101, size=4)

sim = EFBPSim(
    memory=2, 
    strategies=4,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[86 72 38 86 72]')

# %%
mem = 3
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[61 63 61 64 61]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[62 63 62 65 61]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[63 64 65 62 63]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[63 61 62 63 62]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[70 72 72 69 70]')

# %%
sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[70 72 72 69 70]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[72 72 69 70 72]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=2,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[70 72 72 69 70]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[60 75 52 57 60]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[60 75 52 57 60]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[ 5 97 83 83  5]')

# %%
mem=5
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[60 62 58 57 57]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform"
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# 24
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    distribution="uniform",
    seed=279
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
# Out:
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Text(0.5, 1.0, '[54 74 71 71 45]')

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 54.276666666666664
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
sim = EFBPSim(
    memory=mem, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed = 9
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 56.21
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 54.23
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=3,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90871
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.42666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90871
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 58.303333333333335
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=5,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90872
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 58.35
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=6,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90872
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 59.95666666666666
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=7,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.04
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=8,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.61666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=12,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 56.39
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=20,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 56.306666666666665
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=20,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.83
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=20,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=908733
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 56.54
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 54.71666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=20,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90877
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.5
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Change the tthreshold
#
# mem 10
# strategies 10

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=5
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 20.113333333333333
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=10
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 24.383333333333333
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=15
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 28.186666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=20
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 31.266666666666666
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=25
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 34.48
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=30
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 37.77333333333333
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=35
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 40.35
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=40
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 43.27333333333333
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=45
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 46.156666666666666
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=50
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 49.18666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=55
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 51.86666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=60
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 54.623333333333335
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=65
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 57.45
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=70
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 60.013333333333335
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=75
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 62.39666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=80
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 64.87666666666667
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=85
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 67.1
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=90
)

plt.plot(sim.hist)
plt.title(sim.hist[-5:])
print(sim.hist.mean())
# Out:
# 69.24333333333334
# /Users/rebecca/.pyenv/versions/3.9.5/envs/jupyter/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
mem = 10
hist = rng.choice(101, size=2 * mem)

sim = EFBPSim(
    memory=mem, 
    strategies=10,
    start=hist, 
    n_iter=300,
    agents=100,
    strategy_func=make_normal_strategies,
    seed=90873,
    threshold=95
)

plt.plot(sim.hist)
plt.title(f"t={t}  hist: {sim.hist[-5:]}")
print(sim.hist.mean())
# Out:
# 71.39333333333333

# %% [markdown]
# So it seems like the number of agents hovers around the threshold when the threshold is relatively central.  When the threshold is low or high, attendance remains more central than the threshold.  Can we explain why with math?

# %%
mem = 5
hist = rng.choice(101, size=2 * mem)

for t in np.arange(5, 100, 5):
    
    sim = EFBPSim(
        memory=mem, 
        strategies=10,
        start=hist, 
        n_iter=300,
        agents=100,
        strategy_func=make_normal_strategies,
        seed=rng.choice(100000),
        threshold=t
    )

    plt.figure()
    plt.plot(sim.hist)
    plt.title(f"t={t}  hist: {sim.hist[-5:]}")
    print(sim.hist.mean())
# Out:
# 26.92
# 30.316666666666666
# 35.12
# 36.43333333333333
# 38.93
# 42.63666666666666
# 44.72666666666667
# 47.31666666666667
# 47.763333333333335
# 52.306666666666665
# 52.973333333333336
# 54.35666666666667
# 60.193333333333335
# 64.10666666666667
# 70.15333333333334
# 70.04
# 71.48666666666666
# 73.25
# 73.75

# %%
mem = 5
hist = rng.choice(101, size=2 * mem)

for t in np.arange(5, 100, 5):
    
    sim = EFBPSim(
        memory=mem, 
        strategies=10,
        start=hist, 
        n_iter=300,
        agents=100,
        distribution="uniform",
        seed=rng.choice(100000),
        threshold=t
    )

    plt.figure()
    plt.plot(sim.hist)
    plt.title(f"t={t}  hist: {sim.hist[-5:]}")
    print(sim.hist.mean())
# Out:
# 29.09
# 37.736666666666665
# 37.86333333333334
# 41.373333333333335
# 41.04333333333334
# 45.06
# 47.986666666666665
# 50.17
# 54.22
# 54.61
# 56.11666666666667
# 58.8
# 58.95
# 62.60666666666667
# 65.28333333333333
# 66.10666666666667
# 74.39666666666666
# 75.73
# 80.13666666666667
